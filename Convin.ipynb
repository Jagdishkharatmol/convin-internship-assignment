# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
inputs=pd.read_csv("/content/gdrive/MyDrive/Colab Notebooks/data.txt")

# %%
inputs.head()
# Out:
#           hindi movies for adults
# 0             are panda dogs real
# 1        asuedraw winning numbers
# 2         sentry replacement keys
# 3  rebuilding nicad battery packs
# 4   can you overdose on melatonin

# %%
inputs["question"]=inputs["hindi movies for adults"].apply(lambda x:"yes" if 'what' in x else ('yes' if 'how' in x else ('yes' if 'where' in x else ('yes' if 'when' in x else('yes' if 'where' in x else 'no')))))

# %%
inputs.head(20)
# Out:
#              hindi movies for adults question
# 0                are panda dogs real       no
# 1           asuedraw winning numbers       no
# 2            sentry replacement keys       no
# 3     rebuilding nicad battery packs       no
# 4      can you overdose on melatonin       no
# 5                   list of browsers       no
# 6          que son numeros naturales       no
# 7                   mini motos honda       no
# 8                            mulatto       no
# 9                  gene autry museum       no
# 10                         dominicks       no
# 11                             wordz       no
# 12            all super bowl winners       no
# 13  townhouse with garage floor plan       no
# 14       teacher appreciation quotes       no
# 15              outdoor wooden steps       no
# 16                   ceramic classes       no
# 17              boletos primera plus       no
# 18         how to build a shower pan      yes
# ...

# %%
inputs.to_csv("output.csv")
